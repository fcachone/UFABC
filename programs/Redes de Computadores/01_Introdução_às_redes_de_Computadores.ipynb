# %% [markdown]
# # Introdução às redes
#
#
# ---

# %% [markdown]
# ### Metodologia e aborgadem
# *   Metodologia top-down
# *   Ententer os conceitos básicos de redes de computadores

# %% [markdown]
# ### O que são redes?
#   São aglomerados de softwares e hardwares
#
#   Dicionário Houaiss: sistema constitído pela interligação de dois ou mais computados e seus periféricos, com o objetivos de comunicalçao, compartilhamento e intercâmbio de dados.

# %% [markdown]
# ### Componentes
# * Hardware\
#   Computadores, smartphones, roteadores, switches, servidores, etc.
#
# * Software\
#   TCP/IP, OpenFlow, HTTP, e-mail, browsers, etc.

# %% [markdown]
# ### O que é a Internet?
# * Implementação de uma rede.
# * Elementos de computação interligados.
# * Enlaces de comunicação:\
#   fibra, rádio, satélite, etc.

# %% [markdown]
# ### O que é um protocolo?
# * Protocolos humanos
#   1. "Que horas são?"
#   2. "Eu tenho uma pergunta."
#   3. Apresentações.
#   4. ... mensagens específicas enviadas.
#   5. ... ações específicas tomadas quando mensagens são recebidas ou outros eventos.
#
# * Protocolos de rede
#   1. Máquinas em vez de humanos.
#   2. Toda atividade de comunicação na internet é governada por protocolos.
#
# * Protocolos definem regras que:
#  1. Estabelecem os formatos e a ordem das mensagens.
#  2. As ações a serem tomadas na transmissão e recepção das mensagens.

# %% [markdown]
# ### Estrutura da Rede
# * **Borda da rede:** aplicações e hospedeiros.
# * **Núcleo da rede:** roteadores e rede de redes.
# * Redes de acesso (meio físico): enlaces de comunicação.

# %% [markdown]
# ### Borda da Rede
# Existem dois tipos de serviço:
# * Orientado à conexão (e.g. telefonema)\
#   Uma conexão deve ser criada antes de comunicar.\
#   Exemplos de protocolo: **TCP**
#
# * Sem conexão (e.g. correspondência)\
#   Não há necessidade de estabelecer uma conexão.\
#   Exemplo de protocolo: **UDP**
#
# ### TCP
# * Aplicações usando TCP:
#   * HTTP (Web)
#   * FTP (transferência de arquivo)
#   * SMTP (e-mail)
#
# ### UDP
# * Aplicações usando UDP:
#   * streaming media
#   * teleconferência
#   * telefonia IP

# %% [markdown]
# ### Núcleo da Rede
# Múltiplos roteadores interconectados.\
# Existem duas formas de transferir dados na rede:
# * **Comutação de circuitos:** usa um canal dedicado para cada conexão.\
# Ex: dirigir com uma rota fixa
#
# * **Comutação de pacotes:** dados sao enviados em "blocos" discretos.\
# Ex: dirigir com mudança de rotas dinamicamente

# %% [markdown]
# ### Comutação de circuitos: FDM e TDM
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Comutação de pacotes
# Cada fluxo de dados é dividido em pacotes.
# * Melhor uso dos recursos compartilhados
# * Pacote usa toda a banda disponível
# * Não há reserva no início
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Roteamento
#
# Objetivo do Roteamento: mover pacotes entre roteadores da origem ao destino.
#
# * **Redes datagrama**
#   * Endereço de destino determina o próximo salto.
#   * Rotas podem mudar durante uma sessão.
#   * Analogia: dirigir perguntando o caminho.
#
# * **Rede de circuitos virtuais**
#   * Cada pacote leva um número (virtual circuit ID), o número determina o próximo salto.
#   * O caminho é fixo e escolhido no instante de estabelecimento da conexão, permanece fixo durante toda a conexão.
#   * Analogia: dirigir já sabendo a rota.
#
# Diferença: um usa endereço de destino enquanto o outro o ID do circuito para rotear pacotes.

# %% [markdown]
# # Questões
#
#
# ---

# %% [markdown]
# **1) Quantas conexões são possíveis de serem implementadas em uma comutação de circuitos de f canais e de tslots?**
#
# R.:

# %% [markdown]
# **2) A transmissão de um vídeo Youtubefunciona melhor em uma rede de circuitos virtuais ou de uma rede de datagramas? E a transmissão de um arquivo em serviço FTP(File Transfer Protocol)?**
#
# R.:

# %% [markdown]
# **3) Qual a outra implementação de rede (além da Internet) segue o modelo OSI? Desenhe a pilha de protocolos dessa rede que você mencionou.**
#
# R.:

# %% [markdown]
# **4) Por que os softwares das redes de computadores são construídos em camadas? O que se ganha com isso e o que se perde com isso?**
#
# R.:

# %% [markdown]
# **5) Onde geralmente as redes acomodam a maior parte do software da rede? Na periferia ou no núcleo da rede? Por quê?**
#
# R.:

# %% [markdown]
# **6) Por que algumas tecnologias de redes como o ATM (Asynchronous Transfer Mode) e o WIMAX acabaram “morrendo”?**
#
# R:
