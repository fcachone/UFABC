# %% [markdown]
# 1. Imprimir apenas as colunas 'Date' e 'Close'
# 2. Fazer a media artimetica dos volumes de 7 em 7 dias
# 3. Fazer o grafico dos volumes a cada 7 dias

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Bitstamp_BTCUSD_d.csv')
df.head()

# %%
for i in range(len(df)):
  Close = df.iloc[i,6]
  Date = df.iloc[i,1]
  print ('Data:',Date,'Close:',Close)

# %% [markdown]
# **MÉDIAS**

# %%
for i in range(0,2151,7):
    VolumeB = df.iloc[i,7]
media = np.mean(VolumeB)
print('\nA média do Volume BTC é:', media, '\n' )
# Out:
# A média do Volume BTC é: 7245.19

# %%
for i in range(0,2151,7):
    VolumeU = df.iloc[i,8]
media = np.mean(VolumeU)
print('\nA média do Volume UDS é:', media, '\n' )
# Out:
# A média do Volume UDS é: 2746157.05

# %% [markdown]
# **GRAFICOS**

# %%
for i in range(0,2151,7):
    SDays = df.iloc[i,1]

x=df['Unix Timestamp']
y=df['Volume BTC']
plt.figure(dpi=100, facecolor = 'g')
plt.plot(x,y,'m-',label='Volume BTC')
plt.legend(loc='best')
plt.grid(color='k', linestyle= '-.', linewidth= 0.2)
